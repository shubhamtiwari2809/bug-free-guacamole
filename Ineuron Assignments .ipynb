# %% [markdown]
# Python basic assignment 2(practical)
#
# 1:
#
# km = int(input('Enter km: '))
#
# miles = km * 0.62137119
#
# print(miles)
#
# 2:
#
# Celcius = int(input('Enter celcius(in temp): '))
#
# Fahernheit = Celcius * (9/5) + 32
#
# print(Fahernheit)
#
# 3:
#
# import calendar
#
# print(calendar.calendar(2022)) # This will print the calendar of year 2022
#
# 4:
#
# a = int(input('Enter a: '))
# b = int(input('Enter b: '))
# c = int(input('Enter c: '))
#
# dis = b*b - 4*a*c
#
# if a == 0:
#     print('Input correct quadratic equation')
#
# else:
#     if dis > 0:
#         print('real and different roots')
#         x1 = ((-b) + (dis**0.5))/(2*a)
#         x2 = ((-b) - (dis**0.5))/(2*a)
#         print(x1)
#         print(x2)
#
#     elif dis == 0:
#         print('real and same roots')
#         x = (-b)/(2*a)
#         print(x)
#
#     else:
#         print('complex roots')
#         x1 = ((-b) + (dis**0.5))/(2*a)
#         x2 = ((-b) - (dis**0.5))/(2*a)
#         print(x1)
#         print(x2)
#
# 5:
#
# a = int(input('Enter first number: '))
# b = int(input('Enter second number: '))
#
# a,b = b,a
#
# print(a)
# print(b)
